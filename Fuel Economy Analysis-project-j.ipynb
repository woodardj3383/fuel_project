# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df_alpha_08=pd.read_csv('./all_alpha_08.csv')
df_alpha_18=pd.read_csv('./all_alpha_18.csv')
df_alpha_08

# df_alpha_18.head()
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# ...           ...    ...      ...      ...   ...       ...        ...  ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA   B5
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA   B5
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA   B5
#
# ...

# %%
df_alpha_08.head()
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
#
#    Underhood ID    Veh Class Air Pollution Score FE Calc Appr City MPG  \
# 0  8HNXT03.7PKR          SUV                   7          Drv       15
# 1  8HNXT03.7PKR          SUV                   6          Drv       15
# 2  8HNXT02.3DKR          SUV                   7          Drv       17
# 3  8HNXT02.3DKR          SUV                   6          Drv       17
# 4  8HNXV03.5HKR  midsize car                   7          Drv       16
#
#   Hwy MPG Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# ...

# %% [markdown]
# ## Number of columns per dataset

# %%
# correct answer but less detailed
shape=df_alpha_08.shape
shape18=df_alpha_18.shape
shape
# Out:
# (2404, 18)

# %%
#more detailed way
df_alpha_08.info()
df_alpha_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2404 entries, 0 to 2403
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 2404 non-null   object
#  1   Displ                 2404 non-null   float64
#  2   Cyl                   2205 non-null   object
#  3   Trans                 2205 non-null   object
#  4   Drive                 2311 non-null   object
#  5   Fuel                  2404 non-null   object
#  6   Sales Area            2404 non-null   object
#  7   Stnd                  2404 non-null   object
#  8   Underhood ID          2404 non-null   object
#  9   Veh Class             2404 non-null   object
#  10  Air Pollution Score   2404 non-null   object
#  11  FE Calc Appr          2205 non-null   object
#  12  City MPG              2205 non-null   object
#  13  Hwy MPG               2205 non-null   object
#  14  Cmb MPG               2205 non-null   object
# ...

# %% [markdown]
# ## Number of records per dataset

# %%
shape18
# The abovd mmethod shows the same method and is also moer detialed than this method
# Out:
# (1611, 18)

# %% [markdown]
# ## Number of duplicate rows

# %%
# dt=df_alpha_08.duplicated(subset=None, keep='first')
# dt18=df_alpha_18.duplicated(subset=None, keep='first')
# dt18
print(df_alpha_08.duplicated().sum())
print(df_alpha_18.duplicated().sum())
# Out:
# 25
# 0

# %% [markdown]
# ## Features with missing values

# %%
# this method shows which columns in which df have columns wth null values
print(df_alpha_08.isnull().sum())
print(df_alpha_18.isnull().sum())
# Out:
# Model                     0
# Displ                     0
# Cyl                     199
# Trans                   199
# Drive                    93
# Fuel                      0
# Sales Area                0
# Stnd                      0
# Underhood ID              0
# Veh Class                 0
# Air Pollution Score       0
# FE Calc Appr            199
# City MPG                199
# Hwy MPG                 199
# Cmb MPG                 199
# Unadj Cmb MPG           199
# Greenhouse Gas Score    199
# SmartWay                  0
# dtype: int64
# Model                   0
# Displ                   2
# Cyl                     2
# Trans                   0
# Drive                   0
# Fuel                    0
# Cert Region             0
# Stnd                    0
# Stnd Description        0
# Underhood ID            0
# Veh Class               0
# Air Pollution Score     0
# City MPG                0
# Hwy MPG                 0
# Cmb MPG                 0
# ...

# %% [markdown]
# ## Non-null unique values

# %%
# a=df_alpha_08.Fuel.nunique()
# b=df_alpha_18.Fuel.nunique()
# print(f'{a},{b}')
print(df_alpha_08.nunique())
print(df_alpha_18.nunique())
#  this shows the same format as above, but fills in the number of unique values for each column. Example, there are
# 436 different models of vehicles in the first data set, but only 8 different measurements  of cylinders(in general 
# vehicles will only have a certain number of cylnders while there could be a much larger number of different models)
# Out:
# Model                   436
# Displ                    47
# Cyl                       8
# Trans                    14
# Drive                     2
# Fuel                      5
# Sales Area                3
# Stnd                     12
# Underhood ID            343
# Veh Class                 9
# Air Pollution Score      13
# FE Calc Appr              2
# City MPG                 39
# Hwy MPG                  43
# Cmb MPG                  38
# Unadj Cmb MPG           721
# Greenhouse Gas Score     20
# SmartWay                  2
# dtype: int64
# Model                   367
# Displ                    36
# Cyl                       7
# Trans                    26
# Drive                     2
# Fuel                      5
# Cert Region               2
# Stnd                     19
# Stnd Description         19
# Underhood ID            230
# Veh Class                 9
# Air Pollution Score       6
# City MPG                 58
# Hwy MPG                  62
# ...

# %% [markdown]
# ## Count of unique fuel types

# %%
# a=df_alpha_08.Fuel.nunique()
# b=df_alpha_18.Fuel.nunique()
# print(f'{a},{b}')

print(df_alpha_08.Fuel.value_counts())
#  this command actually lists the gas types along with the number of vehicles with that value

print(df_alpha_18.Fuel.value_counts())
# Out:
# Gasoline       2318
# ethanol/gas      72
# diesel           11
# CNG               2
# ethanol           1
# Name: Fuel, dtype: int64
# Gasoline                1492
# Ethanol/Gas               55
# Diesel                    38
# Gasoline/Electricity      24
# Electricity                2
# Name: Fuel, dtype: int64

# %%
df_alpha_08.groupby('Fuel').Fuel.count()
# This is the equivalent of the code above, but written as a SQL statement
# Out:
# Fuel
# CNG               2
# Gasoline       2318
# diesel           11
# ethanol           1
# ethanol/gas      72
# Name: Fuel, dtype: int64

# %% [markdown]
# ## Drop unneeded columns

# %%
df_alpha_08=df_alpha_08.rename(columns=lambda x:x.replace(' ','_'))
df_alpha_18=df_alpha_18.rename(columns=lambda x:x.replace(' ','_'))

# %%
df_alpha_08.drop(['Trans', 'Stnd', 'Underhood_ID', 'FE_Calc_Appr', 'Unadj_Cmb_MPG'], axis=1, inplace=True)

# %%
df_alpha_18.drop(['Trans', 'Stnd', 'Stnd_Description', 'Underhood_ID', 'Comb_CO2'], axis=1, inplace=True)

# %%
print(df_alpha_08.columns)
print(df_alpha_18.columns)
# Out:
# Index(['Model', 'Displ', 'Cyl', 'Drive', 'Fuel', 'Cert_Region', 'Veh_Class',
#        'Air_Pollution_Score', 'City_MPG', 'Hwy_MPG', 'Cmb_MPG',
#        'Greenhouse_Gas_Score', 'SmartWay'],
#       dtype='object')
# Index(['Model', 'Displ', 'Cyl', 'Drive', 'Fuel', 'Cert_Region', 'Veh_Class',
#        'Air_Pollution_Score', 'City_MPG', 'Hwy_MPG', 'Cmb_MPG',
#        'Greenhouse_Gas_Score', 'SmartWay'],
#       dtype='object')

# %% [markdown]
# ## Rename 'Sales Area' column in 2008 dataframe

# %%
df_alpha_08.rename(columns={'Sales_Area':'Cert_Region'}, inplace = True)
print(df_alpha_08.columns)
print(df_alpha_18.columns)
# Out:
# Index(['Model', 'Displ', 'Cyl', 'Trans', 'Drive', 'Fuel', 'Cert_Region',
#        'Stnd', 'Underhood_ID', 'Veh_Class', 'Air_Pollution_Score',
#        'FE_Calc_Appr', 'City_MPG', 'Hwy_MPG', 'Cmb_MPG', 'Unadj_Cmb_MPG',
#        'Greenhouse_Gas_Score', 'SmartWay'],
#       dtype='object')
# Index(['Model', 'Displ', 'Cyl', 'Drive', 'Fuel', 'Cert_Region', 'Veh_Class',
#        'Air_Pollution_Score', 'City_MPG', 'Hwy_MPG', 'Cmb_MPG',
#        'Greenhouse_Gas_Score', 'SmartWay'],
#       dtype='object')

# %%
(df_alpha_08.columns==df_alpha_18.columns).all()
# Out:
# True

# %%
copy_test_08=df_alpha_08.copy()
copy_test_08
# Out:
#             Model  Displ      Cyl Drive      Fuel Cert_Region    Veh_Class  \
# 0       ACURA MDX    3.7  (6 cyl)   4WD  Gasoline          CA          SUV
# 1       ACURA MDX    3.7  (6 cyl)   4WD  Gasoline          FA          SUV
# 2       ACURA RDX    2.3  (4 cyl)   4WD  Gasoline          CA          SUV
# 3       ACURA RDX    2.3  (4 cyl)   4WD  Gasoline          FA          SUV
# 4        ACURA RL    3.5  (6 cyl)   4WD  Gasoline          CA  midsize car
# ...           ...    ...      ...   ...       ...         ...          ...
# 2399  VOLVO XC 90    3.2  (6 cyl)   4WD  Gasoline          CA          SUV
# 2400  VOLVO XC 90    4.4  (8 cyl)   4WD  Gasoline          CA          SUV
# 2401  VOLVO XC 90    3.2  (6 cyl)   2WD  Gasoline          FA          SUV
# 2402  VOLVO XC 90    3.2  (6 cyl)   4WD  Gasoline          FA          SUV
# 2403  VOLVO XC 90    4.4  (8 cyl)   4WD  Gasoline          FA          SUV
#
# ...

# %% [markdown]
# ## Make more consistent column labels

# %%
df_alpha_08.rename(columns=lambda x:x.replace(' ', '_').lower(), inplace=True)

# %%
df_alpha_18.rename(columns=lambda x:x.replace(' ', '_').lower(), inplace=True)

# %%
df_alpha_18.columns
# Out:
# Index(['model', 'displ', 'cyl', 'drive', 'fuel', 'cert_region', 'veh_class',
#        'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
#        'greenhouse_gas_score', 'smartway'],
#       dtype='object')

# %% [markdown]
# # Compare columns names and make sure they're the same

# %%
f'{df_alpha_08.columns} and {df_alpha_18.columns}'
# Out:
# "Index(['model', 'displ', 'cyl', 'drive', 'fuel', 'cert_region', 'veh_class',\n       'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',\n       'greenhouse_gas_score', 'smartway'],\n      dtype='object') and Index(['model', 'displ', 'cyl', 'drive', 'fuel', 'cert_region', 'veh_class',\n       'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',\n       'greenhouse_gas_score', 'smartway'],\n      dtype='object')"

# %% [markdown]
# # CHECKPOINT: SAVE EVERYTHING THUS FAR INTO A DATAFRAME

# %%
df_alpha_08.to_csv('df_alpha_08_v2.csv', index=False)
df_alpha_18.to_csv('df_alpha_18_v2.csv', index=False)

# %% [markdown]
# ## Only return records with a 'CA' cert_region

# %%
df_alpha_08  = df_alpha_08.query('cert_region == "CA"')
print(df_alpha_08.head())
df_alpha_18  = df_alpha_18.query('cert_region == "CA"')
df_alpha_18.head()
# Out:
#        model  displ      cyl drive      fuel cert_region    veh_class  \
# 0  ACURA MDX    3.7  (6 cyl)   4WD  Gasoline          CA          SUV
# 2  ACURA RDX    2.3  (4 cyl)   4WD  Gasoline          CA          SUV
# 4   ACURA RL    3.5  (6 cyl)   4WD  Gasoline          CA  midsize car
# 6   ACURA TL    3.2  (6 cyl)   2WD  Gasoline          CA  midsize car
# 7   ACURA TL    3.5  (6 cyl)   2WD  Gasoline          CA  midsize car
#
#   air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 0                   7       15      20      17                    4       no
# 2                   7       17      22      19                    5       no
# 4                   7       16      24      19                    5       no
# 6                   7       18      26      21                    6      yes
# 7                   7       17      26      20                    6      yes
#        model  displ  cyl drive      fuel cert_region  veh_class  \
# ...

# %% [markdown]
# ## Drop 'cert_region' column from each df, since our 'cert_region' is implied

# %%
df_alpha_08.drop(columns=['cert_region'], axis=1, inplace=True)
df_alpha_18.drop(columns=['cert_region'], axis=1, inplace=True)
df_alpha_18
# Out:
# /Users/joshuawoodard/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4162: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#             model  displ  cyl drive                  fuel     veh_class  \
# 1       ACURA RDX    3.5  6.0   2WD              Gasoline     small SUV
# 3       ACURA RDX    3.5  6.0   4WD              Gasoline     small SUV
# 4       ACURA TLX    2.4  4.0   2WD              Gasoline     small car
# 6       ACURA TLX    3.5  6.0   2WD              Gasoline     small car
# 8       ACURA TLX    3.5  6.0   4WD              Gasoline     small car
# ...           ...    ...  ...   ...                   ...           ...
# 1601  VOLVO XC 60    2.0  4.0   4WD  Gasoline/Electricity     small SUV
# ...

# %% [markdown]
# ## Drop records with missing values

# %%
df_alpha_08
# Out:
#             model  displ      cyl drive      fuel      veh_class  \
# 0       ACURA MDX    3.7  (6 cyl)   4WD  Gasoline            SUV
# 2       ACURA RDX    2.3  (4 cyl)   4WD  Gasoline            SUV
# 4        ACURA RL    3.5  (6 cyl)   4WD  Gasoline    midsize car
# 6        ACURA TL    3.2  (6 cyl)   2WD  Gasoline    midsize car
# 7        ACURA TL    3.5  (6 cyl)   2WD  Gasoline    midsize car
# ...           ...    ...      ...   ...       ...            ...
# 2394    VOLVO V70    3.2  (6 cyl)   2WD  Gasoline  station wagon
# 2396  VOLVO XC 70    3.2  (6 cyl)   4WD  Gasoline            SUV
# 2398  VOLVO XC 90    3.2  (6 cyl)   2WD  Gasoline            SUV
# 2399  VOLVO XC 90    3.2  (6 cyl)   4WD  Gasoline            SUV
# 2400  VOLVO XC 90    4.4  (8 cyl)   4WD  Gasoline            SUV
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 0                      7       15      20      17                    4
# ...

# %%
df_alpha_18.head()
# Out:
#        model  displ  cyl drive      fuel  veh_class  air_pollution_score  \
# 1  ACURA RDX    3.5  6.0   2WD  Gasoline  small SUV                    3
# 3  ACURA RDX    3.5  6.0   4WD  Gasoline  small SUV                    3
# 4  ACURA TLX    2.4  4.0   2WD  Gasoline  small car                    3
# 6  ACURA TLX    3.5  6.0   2WD  Gasoline  small car                    3
# 8  ACURA TLX    3.5  6.0   4WD  Gasoline  small car                    3
#
#   city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score smartway
# 1       20      28      23                     5       No
# 3       19      27      22                     4       No
# 4       23      33      27                     6       No
# 6       20      32      24                     5       No
# 8       21      30      24                     5       No

# %%
df_alpha_08.dropna(inplace=True)
df_alpha_18.dropna(inplace=True)
# Out:
# <ipython-input-35-384eca1009c8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_alpha_08.dropna(inplace=True)

# %% [markdown]
# # CHECKPOINT: SAVE EVERYTHING TO .CSV

# %%
df_alpha_08.to_csv('df_alpha_08_v3.csv', index=False)
df_alpha_18.to_csv('df_alpha_18_v3.csv', index=False)

# %% [markdown]
# ## Fix all datatypes

# %%
df_alpha_18.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                     float64
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score       int64
# city_mpg                 object
# hwy_mpg                  object
# cmb_mpg                  object
# greenhouse_gas_score      int64
# smartway                 object
# dtype: object

# %%
df_alpha_08.cyl = df_alpha_08.cyl.str.extract('(\d+)').astype(int)
# Out:
# /Users/joshuawoodard/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5165: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_alpha_18.cyl = df_alpha_18.cyl.astype(int)

# %% [markdown]
# # CHECKPOINT: SAVE EVERYTHING TO .CSV

# %%
df_alpha_08.to_csv('df_alpha_08_v4.csv',index=False)
df_alpha_18.to_csv('df_alpha_18_v4.csv',index=False)

# %% [markdown]
# ## Change datatypes in 'air_pollution' column

# %%
# ?

# %% [markdown]
# ## Find records with slashed '/' values and separate them into their own separate records

# %%
hybrid_08 = df_alpha_08[df_alpha_08.fuel.str.contains('/')]
df_alpha_08.columns
hybrid_08
# Out:
#                    model  displ  cyl drive         fuel  veh_class  \
# 1550  MERCEDES-BENZ C300    3.0    6   2WD  ethanol/gas  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1550                 6/4    13/18   19/25   15/21                  7/6
#
#      smartway
# 1550       no

# %%
df1 = hybrid_08.copy()
df2 = hybrid_08.copy()

df1
# Out:
#                    model  displ  cyl drive         fuel  veh_class  \
# 1550  MERCEDES-BENZ C300    3.0    6   2WD  ethanol/gas  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1550                 6/4    13/18   19/25   15/21                  7/6
#
#      smartway
# 1550       no

# %%
'ethanol/gas'.split('/')
# Out:
# ['ethanol', 'gas']

# %%
columns_to_split = ['fuel', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg', 'greenhouse_gas_score']

# %%
for c in columns_to_split:
    df1[c] = df1[c].apply(lambda x:x.split('/')[0])
    df2[c] = df2[c].apply(lambda x:x.split('/')[1])

# %%
df1.append(df2)
# Out:
#                    model  displ  cyl drive     fuel  veh_class  \
# 1550  MERCEDES-BENZ C300    3.0    6   2WD  ethanol  small car
# 1550  MERCEDES-BENZ C300    3.0    6   2WD      gas  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1550                   6       13      19      15                    7
# 1550                   4       18      25      21                    6
#
#      smartway
# 1550       no
# 1550       no

# %%
df_alpha_08.drop(hybrid_08.index, inplace=True)
df_alpha_08 = df_alpha_08.append(df1.append(df2), ignore_index=True)
# Out:
# /Users/joshuawoodard/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4162: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_alpha_18[df_alpha_18.fuel.str.contains('/')]
# Out:
#                                   model  displ  cyl drive  \
# 108                            BMW 330e    2.0    4   2WD
# 160                            BMW 530e    2.0    4   2WD
# 162                            BMW 530e    2.0    4   4WD
# 188                            BMW 740e    2.0    4   4WD
# 382                    CHEVROLET Impala    3.6    6   2WD
# 394              CHEVROLET Silverado 15    4.3    6   2WD
# 396              CHEVROLET Silverado 15    4.3    6   4WD
# 398              CHEVROLET Silverado 15    5.3    8   2WD
# 428             CHEVROLET Suburban 1500    5.3    8   2WD
# 432             CHEVROLET Suburban 1500    5.3    8   4WD
# 436                CHEVROLET Tahoe 1500    5.3    8   2WD
# 440                CHEVROLET Tahoe 1500    5.3    8   4WD
# 454                      CHEVROLET Volt    1.5    4   2WD
# 456                      CHEVROLET Volt    1.5    4   2WD
# 458                        CHRYSLER 300    3.6    6   2WD
# ...

# %%
hybrid_18 = df_alpha_18[df_alpha_18.fuel.str.contains('/')]

df1 = hybrid_18.copy()
df2 = hybrid_18.copy()

columns_to_split = ['fuel', 'city_mpg', 'hwy_mpg', 'cmb_mpg']

for c in columns_to_split:
    df1[c] = df1[c].apply(lambda x:x.split('/')[0])
    df2[c] = df2[c].apply(lambda x:x.split('/')[1])
    
df_alpha_18.drop(hybrid_18.index, inplace=True)
df_alpha_18 = df_alpha_18.append(df1.append(df2), ignore_index=True)

# %%
df_alpha_18[df_alpha_18.city_mpg.str.contains('/')]
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df_alpha_08.fuel.value_counts()
# Out:
# Gasoline    1007
# gas            1
# ethanol        1
# CNG            1
# Name: fuel, dtype: int64

# %%
#  for i in range(len(df_alpha_18[df_alpha_18['Fuel'].str.contains('/')])):
#         'Model':df_alpha_18['Fuel'].str.contains('/').iloc[i]['Modele']
#         'Dspl':df_alpha_18['Fuel'].str.contains('/').iloc[i]['Model']
#         'Cyl':df_alpha_18['Fuel'].str.contains('/').iloc[i]['Model']
#         'Model':df_alpha_18['Fuel'].str.contains('/').iloc[i]['Model']
#         'Model':df_alpha_18['Fuel'].str.contains('/').iloc[i]['Model']
#         'Model':df_alpha_18['Fuel'].str.contains('/').iloc[i]['Model']
cols=['Fuel','City_MPG','Hwy_MPG','Cmb_MPG']
x = df_alpha_18[df_alpha_18['Fuel'].str.contains('/')].index()
x1=x.copy()
x2=x.copy()
for i in cols:
    x1[i]=x1[i].apply(lambda x:x.split('/')[0])
    x1[i]=x2[i].apply(lambda x:x.split('/')[1])
df_alpha_18

# %% [markdown]
# #### Select all rows with records of slashed values

# %% [markdown]
# ### Repeat for 2018

# %% [markdown]
# ## Gas/Gasoline?

# %%
df_alpha_08.query('fuel == "gas"').copy()
# Out:
#                    model  displ  cyl drive fuel  veh_class  \
# 1009  MERCEDES-BENZ C300    3.0    6   2WD  gas  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1009                   4       18      25      21                    6
#
#      smartway
# 1009       no

# %%
gas_type_08 = df_alpha_08.query('fuel == "gas"').copy()
gas_type_08.replace(to_replace='gas', value='Gasoline', inplace=True)
df_alpha_08.drop(gas_type_08.index, inplace=True)
df_alpha_08 = df_alpha_08.append(gas_type_08)

# %%
gas_type_08 = df_alpha_08.query('fuel == "ethanol"').copy()
gas_type_08.replace(to_replace='ethanol', value='Ethanol', inplace=True)
df_alpha_08.drop(gas_type_08.index, inplace=True)
df_alpha_08 = df_alpha_08.append(gas_type_08)

# %%
df_alpha_08.fuel.value_counts()
# Out:
# Gasoline    1008
# Ethanol        1
# CNG            1
# Name: fuel, dtype: int64

# %%
gas_type_18 = df_alpha_18.query('fuel == "Gas"').copy()
gas_type_18.replace(to_replace='Gas', value='Gasoline', inplace=True)
df_alpha_18.drop(gas_type_18.index, inplace=True)
df_alpha_18 = df_alpha_18.append(gas_type_18)

# %%
df_alpha_18.fuel.value_counts()
# Out:
# Gasoline       778
# Ethanol         26
# Diesel          19
# Electricity     12
# Name: fuel, dtype: int64

# %% [markdown]
# ## Fix `*_mpg, greenhouse_gas_score and air_pollution_score` datatypes

# %%
df_alpha_08.city_mpg = df_alpha_08.city_mpg.astype(int)
df_alpha_08.hwy_mpg = df_alpha_08.hwy_mpg.astype(int)
df_alpha_08.cmb_mpg = df_alpha_08.cmb_mpg.astype(int)

df_alpha_18.city_mpg = df_alpha_18.city_mpg.astype(int)
df_alpha_18.hwy_mpg = df_alpha_18.hwy_mpg.astype(int)
df_alpha_18.cmb_mpg = df_alpha_18.cmb_mpg.astype(int)

# %%
df_alpha_08.air_pollution_score = df_alpha_08.air_pollution_score.astype(float).astype(int)
df_alpha_08.greenhouse_gas_score = df_alpha_08.greenhouse_gas_score.astype(int)

# %%
(df_alpha_18.dtypes == df_alpha_08.dtypes).all()
# Out:
# True

# %% [markdown]
# # CHECKPOINT: SAVE EVERYTHING

# %%
df_alpha_08.to_csv('df_alpha_08_v5.csv', index=False)
df_alpha_18.to_csv('df_alpha_18_v5.csv', index=False)

df_alpha_08 = pd.read_csv('df_alpha_08_v5.csv')
df_alpha_18 = pd.read_csv('df_alpha_18_v5.csv')

# %% [markdown]
# # Create visuals of findings

# %% [markdown]
# ## Fix `greenhouse_gas_score, air_pollution_score` datatypes

# %%
df_alpha_08.greenhouse_gas_score.hist(figsize=(8, 5));

# %%
df_alpha_18.greenhouse_gas_score.hist(figsize=(8, 5));

# %%
df_alpha_08.cmb_mpg.hist(figsize=(8, 5));

# %%
df_alpha_18.cmb_mpg.hist(figsize=(8, 5));

# %%
df_alpha_08.plot(kind='scatter', x='cmb_mpg', y='displ', figsize=(9,6))
plt.title('Combined MPG based on Displacement (2008)')
plt.xlabel('Combined MPG')
plt.ylabel('Displacement');

# %%
df_alpha_18.plot(kind='scatter', x='cmb_mpg', y='displ', figsize=(9,6))
df_alpha_18.plot(kind='line')
plt.title('Combined MPG based on Displacement (2018)')
plt.xlabel('Combined MPG')
plt.ylabel('Displacement');

# %%
df_alpha_08.plot(kind='scatter', x='cmb_mpg', y='cyl', figsize=(9,6))
plt.title('Combined MPG based on no. of Cylinders (2008)')
plt.xlabel('Combined MPG')
plt.ylabel('No. of Cylinders');

# %%
df_alpha_18.plot(kind='scatter', x='cmb_mpg', y='cyl', figsize=(9,6))
plt.title('Combined MPG based on no. of Cylinders (2018)')
plt.xlabel('Combined MPG')
plt.ylabel('No. of Cylinders');

# %%
df_alpha_08.plot(kind='scatter', x='cmb_mpg', y='greenhouse_gas_score', figsize=(9,6))
plt.title('Combined MPG based on Greenhouse Gas Score (2008)')
plt.xlabel('Combined MPG')
plt.ylabel('Greenhouse Gas Score');

# %%
df_alpha_18.plot(kind='scatter', x='cmb_mpg', y='greenhouse_gas_score', figsize=(9,6))
plt.title('Combined MPG based on Greenhouse Gas Score (2018)')
plt.xlabel('Combined MPG')
plt.ylabel('Greenhouse Gas Score');

# %% [markdown]
# ## How many more car models use alternative fuels in 2018 as opposed to 2008?
# * ### May need to Google the answer to find out which fuel types are considered 'alternative'

# %%
fe_08 = df_alpha_08.cmb_mpg.mean()
fe_18 = df_alpha_18.cmb_mpg.mean()

# %%
plt.subplots(figsize=(9, 6))
plt.bar(['2008', '2018'], [fe_08, fe_18], color=['black', 'gold']);

# %%
fe_08 = df_alpha_08.copy()
fe_18 = df_alpha_18.copy()

fe_18.drop(fe_18.query('veh_class == "special purpose"').index, inplace=True)

# %%
fe_18.query('veh_class == "special purpose"')
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
fe_18[fe_18['veh_class'] == 'small SUV'].copy()
# Out:
#                            model  displ  cyl drive         fuel  veh_class  \
# 0                      ACURA RDX    3.5    6   2WD     Gasoline  small SUV
# 1                      ACURA RDX    3.5    6   4WD     Gasoline  small SUV
# 28                       AUDI Q5    2.0    4   4WD     Gasoline  small SUV
# 37                      AUDI SQ5    3.0    6   4WD     Gasoline  small SUV
# 119                  BMW X4 M40i    3.0    6   4WD     Gasoline  small SUV
# ..                           ...    ...  ...   ...          ...        ...
# 795                  VOLVO XC 60    2.0    4   4WD     Gasoline  small SUV
# 807                  VOLVO XC 60    2.0    4   4WD  Electricity  small SUV
# 828                JEEP Cherokee    2.4    4   2WD     Gasoline  small SUV
# 829                JEEP Cherokee    2.4    4   4WD     Gasoline  small SUV
# 831  MERCEDES-BENZ GLA250 4Matic    2.0    4   4WD     Gasoline  small SUV
#
# ...

# %%
columns = ['small SUV', 'standard SUV']

for c in columns:
    records = fe_18[fe_18['veh_class'] == c].copy()
    records.replace(to_replace=c, value='SUV', inplace=True)
    fe_18.drop(fe_18[fe_18['veh_class'] == c].index, inplace=True)
    fe_18 = fe_18.append(records)

# %%
records = fe_18[fe_18['veh_class'] == 'minivan'].copy()
records.replace(to_replace='minivan', value='van', inplace=True)
fe_18.drop(fe_18[fe_18['veh_class'] == 'minivan'].index, inplace=True)
fe_18 = fe_18.append(records)

# %%
records = fe_08[fe_08['veh_class'] == 'minivan'].copy()
records.replace(to_replace='minivan', value='van', inplace=True)
fe_08.drop(fe_08[fe_08['veh_class'] == 'minivan'].index, inplace=True)
fe_08 = fe_08.append(records)

# %% [markdown]
# ## How much has the average fuel economy improved since 2008?

# %%
vt_fe_08 = fe_08.groupby('veh_class').city_mpg.mean()
vt_fe_08
# Out:
# veh_class
# SUV              16.496503
# large car        15.836364
# midsize car      18.792857
# pickup           14.666667
# small car        18.328402
# station wagon    19.633333
# van              14.609756
# Name: city_mpg, dtype: float64

# %% [markdown]
# ## Which type of vehicle's fuel economy has improved the most since 2008?

# %%
fe_08.veh_class.value_counts()
# Out:
# small car        338
# SUV              286
# midsize car      140
# pickup            90
# station wagon     60
# large car         55
# van               41
# Name: veh_class, dtype: int64

# %%
fe_18.veh_class.value_counts()
# Out:
# small car        285
# SUV              195
# midsize car      139
# large car         88
# pickup            78
# station wagon     35
# van                5
# Name: veh_class, dtype: int64

# %%
vt_fe_18= fe_18.groupby('veh_class').city_mpg.mean()
vt_fe_18
# Out:
# veh_class
# SUV              19.133333
# large car        20.420455
# midsize car      24.805755
# pickup           16.551282
# small car        22.561404
# station wagon    24.828571
# van              18.000000
# Name: city_mpg, dtype: float64

# %% [markdown]
# #### (2008) Average fuel economy by vehicle type

# %%
vt_fe_08 = fe_08.groupby('veh_class').city_mpg.mean()
vt_fe_08

# %% [markdown]
# #### (2018) Average fuel economy by vehicle type

# %%
vt_fe_18= fe_18.groupby('veh_class').city_mpg.mean()
vt_fe_18

# %% [markdown]
# ## Which model has the highest `air_pollution_score` and fuel economy in 2008 and 2018? Compare them.

# %%
airmax_08 = df_alpha_08.air_pollution_score.max()
print(airmax_08)

mileage_max_08 = df_alpha_08.cmb_mpg.max()
print(mileage_max_08)
# Out:
# 9
# 46

# %%
best_08 = df_alpha_08.query(f'air_pollution_score == {airmax_08} and cmb_mpg == {mileage_max_08}')
best_08
# Out:
#             model  displ  cyl drive      fuel    veh_class  \
# 899  TOYOTA Prius    1.5    4   2WD  Gasoline  midsize car
#
#      air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  greenhouse_gas_score  \
# 899                    9        48       45       46                    10
#
#     smartway
# 899      yes

# %%
df_alpha_08.query('air_pollution_score == 9')
# Out:
#                                  model  displ  cyl drive      fuel  \
# 58                           BMW 328ci    3.0    6   2WD  Gasoline
# 59                           BMW 328ci    3.0    6   2WD  Gasoline
# 62               BMW 328ci Convertible    3.0    6   2WD  Gasoline
# 63               BMW 328ci Convertible    3.0    6   2WD  Gasoline
# 66                          BMW 328cxi    3.0    6   4WD  Gasoline
# ..                                 ...    ...  ...   ...       ...
# 956  VOLKSWAGEN New Beetle Convertible    2.5    5   2WD  Gasoline
# 967                  VOLKSWAGEN Rabbit    2.5    5   2WD  Gasoline
# 968                  VOLKSWAGEN Rabbit    2.5    5   2WD  Gasoline
# 979                          VOLVO S40    2.4    5   2WD  Gasoline
# 996                          VOLVO V50    2.4    5   2WD  Gasoline
#
#          veh_class  air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  \
# 58       small car                    9        20       30       24
# ...

# %%
best_08_model = best_08.iloc[0].model
best_mpg_08 = best_08.iloc[:, 7:10].iloc[0]
best_mpg_08
# Out:
# city_mpg    48
# hwy_mpg     45
# cmb_mpg     46
# Name: 899, dtype: int64

# %%
airmax_18 = df_alpha_18.air_pollution_score.max()
airmax_18
# Out:
# 7

# %%
mileage_max_18 = df_alpha_18.cmb_mpg.max()
mileage_max_18
# Out:
# 106

# %%
best_18 = df_alpha_18.query(f'air_pollution_score == {airmax_18} and cmb_mpg == {mileage_max_18}')
best_model_18 = best_18.iloc[0].model
best_mpg_18 = best_18.iloc[:, 7:10].iloc[0]
best_mpg_18
# Out:
# city_mpg    113
# hwy_mpg      99
# cmb_mpg     106
# Name: 802, dtype: int64

# %%
cars = [f'{best_08_model} (2008)', f'{best_model_18} (2018)']

plt.subplots(figsize=(15, 12))
plt.bar(best_mpg_08.index, best_mpg_08, color='b', edgecolor='black', alpha=0.5)
plt.bar(best_mpg_18.index, best_mpg_18, color='g', edgecolor='black', alpha=0.5)
plt.title('(2008 vs 2018) Most Economic Car by Year', fontsize=16)
plt.ylabel('Fuel Economy', fontsize=14)
plt.xlabel('Categories (MPG)', fontsize=14)
plt.legend(cars, loc='best', prop={'size': 14});
